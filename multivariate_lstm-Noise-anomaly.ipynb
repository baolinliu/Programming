# %% [markdown]
# # Predicting Multiple Time Series data at once (Multi-Variate Time Series)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

from tensorflow.contrib import learn
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from lstm import lstm_model
from data_processing import load_csvdata

# %% [markdown]
# # Energy building data from the UCI repository

# %%
energy = pd.read_csv('data/energydata_complete.csv')
energy =energy[['RH_1','RH_2','RH_3','RH_4','RH_5','RH_6']]
# https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction

# %%
energy.head()
# Out:
#         RH_1       RH_2       RH_3       RH_4   RH_5       RH_6
# 0  47.596667  44.790000  44.730000  45.566667  55.20  84.256667
# 1  46.693333  44.722500  44.790000  45.992500  55.20  84.063333
# 2  46.300000  44.626667  44.933333  45.890000  55.09  83.156667
# 3  46.066667  44.590000  45.000000  45.723333  55.09  83.423333
# 4  46.333333  44.530000  45.000000  45.530000  55.09  84.893333

# %%
# adding noise to the data before having LSTM predict on it
energy_noise = energy.apply(lambda x: np.random.normal(loc=0.0, scale=2)+ x, axis = 1)
# axis 1 does it column wise, or else it won't have the same affect
# More on np.random.normal:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.normal.html

# %%
energy_noise.head()
# Out:
#         RH_1       RH_2       RH_3       RH_4       RH_5       RH_6
# 0  47.981905  45.175238  45.115238  45.951905  55.585238  84.641905
# 1  46.796634  44.825801  44.893301  46.095801  55.303301  84.166634
# 2  48.353923  46.680589  46.987256  47.943923  57.143923  85.210589
# 3  46.549521  45.072854  45.482854  46.206188  55.572854  83.906188
# 4  49.241005  47.437672  47.907672  48.437672  57.997672  87.801005

# %% [markdown]
# # Scaling Data

# %%
min_max_scaler = preprocessing.MinMaxScaler()
energy_scaled = min_max_scaler.fit_transform(energy)
RH_scaled = min_max_scaler.fit_transform(energy_noise)

# %%
plt.figure(figsize=(20,10))
plt.plot(RH_scaled[:,0], label='Noisy Data Scaled')
plt.plot(energy_scaled[:,0],label="Scaled Data")
plt.legend()

# %% [markdown]
# # Setting parameters

# %%
LOG_DIR = './ops_logs/RH_Noise'
TIMESTEPS = 20
RNN_LAYERS = [{'num_units': 10}, {'num_units': 2}]
DENSE_LAYERS = None
TRAINING_STEPS = 20000
PRINT_STEPS = TRAINING_STEPS / 10
BATCH_SIZE = 2000

# %% [markdown]
# # Fitting Model

# %%
regressor = learn.SKCompat(learn.Estimator(
    model_fn=lstm_model(
        TIMESTEPS,
        RNN_LAYERS,
        DENSE_LAYERS
    ),
    model_dir=LOG_DIR
))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c1dc09550>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': './ops_logs/RH_Noise'}

# %%
X, y = load_csvdata(RH_scaled, TIMESTEPS, seperate=False)
# create a lstm instance and validation monitor
validation_monitor = learn.monitors.ValidationMonitor(X['val'], y['val'],
                                                      every_n_steps=PRINT_STEPS,
                                                      early_stopping_rounds=1000)
regressor.fit(X['train'], y['train'], 
              monitors=[validation_monitor], 
              batch_size=BATCH_SIZE,
              steps=TRAINING_STEPS)
# Out:
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:269: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./ops_logs/RH_Noise/model.ckpt.
# INFO:tensorflow:loss = 0.20721, step = 1
# INFO:tensorflow:global_step/sec: 8.64098
# INFO:tensorflow:loss = 0.195636, step = 101 (11.574 sec)
# INFO:tensorflow:global_step/sec: 8.86123
# INFO:tensorflow:loss = 0.183143, step = 201 (11.285 sec)
# INFO:tensorflow:global_step/sec: 8.896
# INFO:tensorflow:loss = 0.177634, step = 301 (11.242 sec)
# INFO:tensorflow:global_step/sec: 9.27671
# INFO:tensorflow:loss = 0.171284, step = 401 (10.779 sec)
# INFO:tensorflow:global_step/sec: 9.00026
# INFO:tensorflow:loss = 0.163828, step = 501 (11.110 sec)
# INFO:tensorflow:global_step/sec: 9.43869
# INFO:tensorflow:loss = 0.153935, step = 601 (10.595 sec)
# INFO:tensorflow:global_step/sec: 9.45357
# INFO:tensorflow:loss = 0.144566, step = 701 (10.579 sec)
# INFO:tensorflow:global_step/sec: 9.52421
# INFO:tensorflow:loss = 0.136441, step = 801 (10.499 sec)
# INFO:tensorflow:global_step/sec: 9.60638
# INFO:tensorflow:loss = 0.128893, step = 901 (10.410 sec)
# INFO:tensorflow:global_step/sec: 9.26257
# INFO:tensorflow:loss = 0.11813, step = 1001 (10.796 sec)
# INFO:tensorflow:global_step/sec: 9.22155
# INFO:tensorflow:loss = 0.111301, step = 1101 (10.844 sec)
# INFO:tensorflow:global_step/sec: 9.77344
# INFO:tensorflow:loss = 0.103957, step = 1201 (10.232 sec)
# INFO:tensorflow:global_step/sec: 9.22883
# INFO:tensorflow:loss = 0.0930713, step = 1301 (10.837 sec)
# INFO:tensorflow:global_step/sec: 9.4137
# INFO:tensorflow:loss = 0.0864839, step = 1401 (10.622 sec)
# INFO:tensorflow:global_step/sec: 9.93484
# INFO:tensorflow:loss = 0.0800776, step = 1501 (10.066 sec)
# INFO:tensorflow:global_step/sec: 9.96627
# INFO:tensorflow:loss = 0.07249, step = 1601 (10.034 sec)
# INFO:tensorflow:global_step/sec: 9.16703
# INFO:tensorflow:loss = 0.06615, step = 1701 (10.909 sec)
# INFO:tensorflow:global_step/sec: 10.0959
# INFO:tensorflow:loss = 0.0617989, step = 1801 (9.905 sec)
# INFO:tensorflow:global_step/sec: 10.1924
# INFO:tensorflow:loss = 0.056884, step = 1901 (9.811 sec)
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-10-18-02:02:03
# INFO:tensorflow:Restoring parameters from ./ops_logs/RH_Noise/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-10-18-02:02:04
# INFO:tensorflow:Saving dict for global step 1: global_step = 1, loss = 0.156617
# INFO:tensorflow:Validation (step 2000): loss = 0.156617, global_step = 1
# INFO:tensorflow:global_step/sec: 5.80554
# INFO:tensorflow:loss = 0.0518796, step = 2001 (17.225 sec)
# INFO:tensorflow:global_step/sec: 10.1297
# INFO:tensorflow:loss = 0.0471239, step = 2101 (9.872 sec)
# INFO:tensorflow:global_step/sec: 10.1111
# INFO:tensorflow:loss = 0.0446226, step = 2201 (9.890 sec)
# INFO:tensorflow:global_step/sec: 10.1263
# INFO:tensorflow:loss = 0.0413006, step = 2301 (9.875 sec)
# INFO:tensorflow:global_step/sec: 10.1323
# INFO:tensorflow:loss = 0.0377901, step = 2401 (9.869 sec)
# INFO:tensorflow:global_step/sec: 10.2064
# INFO:tensorflow:loss = 0.0368471, step = 2501 (9.798 sec)
# INFO:tensorflow:global_step/sec: 10.2053
# INFO:tensorflow:loss = 0.0345783, step = 2601 (9.799 sec)
# INFO:tensorflow:global_step/sec: 10.1236
# INFO:tensorflow:loss = 0.031806, step = 2701 (9.878 sec)
# INFO:tensorflow:global_step/sec: 9.72337
# INFO:tensorflow:loss = 0.0303497, step = 2801 (10.285 sec)
# INFO:tensorflow:global_step/sec: 10.1002
# INFO:tensorflow:loss = 0.0196382, step = 5501 (9.850 sec)
# INFO:tensorflow:global_step/sec: 10.0878
# INFO:tensorflow:loss = 0.0190876, step = 5601 (9.913 sec)
# INFO:tensorflow:global_step/sec: 10.1307
# INFO:tensorflow:loss = 0.0194748, step = 5701 (9.871 sec)
# INFO:tensorflow:global_step/sec: 10.1561
# INFO:tensorflow:loss = 0.0184821, step = 5801 (9.847 sec)
# INFO:tensorflow:Saving checkpoints for 5837 into ./ops_logs/RH_Noise/model.ckpt.
# INFO:tensorflow:global_step/sec: 9.40354
# INFO:tensorflow:loss = 0.0194358, step = 5901 (10.634 sec)
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-10-18-02:08:47
# INFO:tensorflow:Restoring parameters from ./ops_logs/RH_Noise/model.ckpt-5837
# INFO:tensorflow:Finished evaluation at 2017-10-18-02:08:48
# INFO:tensorflow:Saving dict for global step 5837: global_step = 5837, loss = 0.0400457
# INFO:tensorflow:Validation (step 6000): loss = 0.0400457, global_step = 5837
# INFO:tensorflow:global_step/sec: 6.29648
# INFO:tensorflow:loss = 0.0185382, step = 6001 (15.882 sec)
# INFO:tensorflow:global_step/sec: 10.1668
# INFO:tensorflow:loss = 0.019441, step = 6101 (9.836 sec)
# INFO:tensorflow:global_step/sec: 10.1825
# INFO:tensorflow:loss = 0.0189754, step = 6201 (9.820 sec)
# INFO:tensorflow:global_step/sec: 10.1707
# INFO:tensorflow:loss = 0.0183259, step = 6301 (9.832 sec)
# INFO:tensorflow:global_step/sec: 10.1107
# INFO:tensorflow:loss = 0.0191153, step = 6401 (9.891 sec)
# INFO:tensorflow:global_step/sec: 10.2771
# INFO:tensorflow:loss = 0.0183199, step = 6501 (9.730 sec)
# INFO:tensorflow:global_step/sec: 10.1701
# INFO:tensorflow:loss = 0.0187711, step = 6601 (9.832 sec)
# INFO:tensorflow:global_step/sec: 10.1058
anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:672: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-10-18-02:18:51
# INFO:tensorflow:Restoring parameters from ./ops_logs/RH_Noise/model.ckpt-11799
# INFO:tensorflow:Finished evaluation at 2017-10-18-02:18:52
# INFO:tensorflow:Saving dict for global step 11799: global_step = 11799, loss = 0.0281097
# INFO:tensorflow:Validation (step 12000): loss = 0.0281097, global_step = 11799
# INFO:tensorflow:global_step/sec: 6.27947
# INFO:tensorflow:loss = 0.0115026, step = 12001 (15.925 sec)
# INFO:tensorflow:global_step/sec: 10.1705
# INFO:tensorflow:loss = 0.011129, step = 12101 (9.832 sec)
# INFO:tensorflow:global_step/sec: 10.0361
# INFO:tensorflow:loss = 0.0105871, step = 12201 (9.964 sec)
# INFO:tensorflow:global_step/sec: 10.1206
# INFO:tensorflow:loss = 0.0104665, step = 12301 (9.881 sec)
# INFO:tensorflow:global_step/sec: 10.1363
# INFO:tensorflow:loss = 0.0101169, step = 12401 (9.866 sec)
# INFO:tensorflow:global_step/sec: 10.1135
# INFO:tensorflow:loss = 0.00949293, step = 12501 (9.888 sec)
# INFO:tensorflow:global_step/sec: 10.156
# INFO:tensorflow:loss = 0.00944407, step = 12601 (9.846 sec)
# INFO:tensorflow:global_step/sec: 10.1452
# INFO:tensorflow:loss = 0.00936141, step = 12701 (9.857 sec)
# INFO:tensorflow:global_step/sec: 10.0692
# INFO:tensorflow:loss = 0.00885489, step = 12801 (9.931 sec)
# INFO:tensorflow:global_step/sec: 10.0998
# INFO:tensorflow:loss = 0.00846579, step = 12901 (9.901 sec)
# INFO:tensorflow:global_step/sec: 10.0475
# INFO:tensorflow:loss = 0.00793714, step = 13001 (9.953 sec)
deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Starting evaluation at 2017-10-18-02:29:21
# INFO:tensorflow:Restoring parameters from ./ops_logs/RH_Noise/model.ckpt-17517
# INFO:tensorflow:Finished evaluation at 2017-10-18-02:29:22
# INFO:tensorflow:Saving dict for global step 17517: global_step = 17517, loss = 0.00821235
# INFO:tensorflow:Validation (step 18000): loss = 0.00821235, global_step = 17517
# INFO:tensorflow:global_step/sec: 6.0285
# INFO:tensorflow:loss = 0.00588746, step = 18001 (16.588 sec)
# INFO:tensorflow:global_step/sec: 10.0255
# INFO:tensorflow:loss = 0.00605316, step = 18101 (9.975 sec)
# INFO:tensorflow:global_step/sec: 9.89871
# INFO:tensorflow:loss = 0.00621786, step = 18201 (10.102 sec)
# INFO:tensorflow:global_step/sec: 9.68971
# INFO:tensorflow:loss = 0.00604444, step = 18301 (10.320 sec)
# INFO:tensorflow:global_step/sec: 9.10712
# INFO:tensorflow:loss = 0.00603801, step = 18401 (10.981 sec)
# INFO:tensorflow:global_step/sec: 9.62588
# INFO:tensorflow:loss = 0.00608095, step = 18501 (10.388 sec)
# INFO:tensorflow:global_step/sec: 9.61687
# INFO:tensorflow:loss = 0.00603831, step = 18601 (10.398 sec)
# INFO:tensorflow:global_step/sec: 9.91362
# INFO:tensorflow:loss = 0.0058036, step = 18701 (10.087 sec)
# INFO:tensorflow:global_step/sec: 9.70894
# INFO:tensorflow:loss = 0.00592524, step = 18801 (10.300 sec)
# INFO:tensorflow:global_step/sec: 9.90629
# INFO:tensorflow:loss = 0.00594213, step = 18901 (10.095 sec)
# INFO:tensorflow:global_step/sec: 9.95727
# INFO:tensorflow:loss = 0.00603217, step = 19001 (10.043 sec)
# INFO:tensorflow:global_step/sec: 9.36108
# INFO:tensorflow:loss = 0.00606274, step = 19101 (10.682 sec)
# INFO:tensorflow:global_step/sec: 9.67538
# INFO:tensorflow:loss = 0.00611676, step = 19201 (10.335 sec)
# INFO:tensorflow:global_step/sec: 9.72041
# INFO:tensorflow:loss = 0.00611065, step = 19301 (10.288 sec)
# INFO:tensorflow:global_step/sec: 9.95071
# INFO:tensorflow:loss = 0.00605992, step = 19401 (10.050 sec)
# INFO:tensorflow:global_step/sec: 10.001
# INFO:tensorflow:loss = 0.00596198, step = 19501 (9.999 sec)
# INFO:tensorflow:global_step/sec: 9.96489
# INFO:tensorflow:loss = 0.00594303, step = 19601 (10.035 sec)
# INFO:tensorflow:global_step/sec: 9.98772
# INFO:tensorflow:loss = 0.00595265, step = 19701 (10.012 sec)
# INFO:tensorflow:global_step/sec: 9.94811
# INFO:tensorflow:loss = 0.00626105, step = 19801 (10.052 sec)
# INFO:tensorflow:global_step/sec: 9.9072
# INFO:tensorflow:loss = 0.00615641, step = 19901 (10.094 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./ops_logs/RH_Noise/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00610613.
# SKCompat()

# %% [markdown]
# # MSE between predicted and Actual

# %%
predicted = regressor.predict(X['test'])
rmse = np.sqrt(((predicted - y['test']) ** 2).mean(axis=0))
score = mean_squared_error(predicted, y['test'])
print ("MSE: %f" % score)
print ("RMSE: %f" % score)
# since I am training multiple time series data, I need a really small MSE, such as .001 or less
# some predictions fit better than others
# Out:
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/models.py:107: mean_squared_error_regressor (from tensorflow.contrib.learn.python.learn.ops.losses_ops) is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Use `tf.contrib.losses.mean_squared_error` and explicit logits computation.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/ops/losses_ops.py:39: mean_squared_error (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.mean_squared_error instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:539: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /anaconda3/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:151: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.framework.python.ops.arg_scope) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# INFO:tensorflow:Restoring parameters from ./ops_logs/RH_Noise/model.ckpt-20000
# MSE: 0.006452
# RMSE: 0.006452

# %% [markdown]
# # Plotting all Data

# %%
plt.plot(y['test'])
plt.plot(predicted)
# Out:
# [<matplotlib.lines.Line2D at 0x1c1dc09390>,
#  <matplotlib.lines.Line2D at 0x1c2cbe2240>,
#  <matplotlib.lines.Line2D at 0x1c2cbe2400>,
#  <matplotlib.lines.Line2D at 0x1c2cbe25f8>,
#  <matplotlib.lines.Line2D at 0x1c2ef8ae10>,
#  <matplotlib.lines.Line2D at 0x1c2cbe29b0>]

# %% [markdown]
# # Looking at individual time series data

# %%
plt.plot(y['test'][:,0])
plt.plot(predicted[:,0])

# %%
plt.plot(y['test'][:,1])
plt.plot(predicted[:,1])

# %%
plt.plot(y['test'][:,2])
plt.plot(predicted[:,2])

# %%
plt.plot(y['test'][:,3])
plt.plot(predicted[:,3])

# %%
plt.plot(y['test'][:,4])
plt.plot(predicted[:,4])

# %%
plt.plot(y['test'][:,5])
plt.plot(predicted[:,5])
